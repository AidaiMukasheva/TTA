# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = pd.read_csv("Hotels.csv")
data
#print(data)
# Out:
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 0         Spain               7          3.2            220
# 1         Italy               9          4.1            180
# 2      Portugal               5          3.1            134
# 3       Iceland               1          3.5             86
# 4            UK               8          3.7             95
# 5   Switzerland               9          4.2             60
# 6        Sweden               4          3.6             99
# 7       Austria               5          4.0             45
# 8        Russia               4          3.3             89
# 9      Mongolia               1          3.2             32
# 10        Japan               8          4.2             85
# 11  South Korea               3          3.9            110
# 12        China               4          3.1            230
# 13   Kazakhstan               1          3.0            112
# 14          UAE               8          4.6            260
# ...

# %%
#Task 1

data.shape

#There are 16 rows and 6 columns in my table
# Out:
# (16, 6)

# %%
#Task2
#Printinhg rows 3-8 without using loc and iloc

data[3:9]
# Out:
#   Destinations  Feedback score  Star rating  All-inclusive  \
# 3      Iceland               1          3.5             86
# 4           UK               8          3.7             95
# 5  Switzerland               9          4.2             60
# 6       Sweden               4          3.6             99
# 7      Austria               5          4.0             45
# 8       Russia               4          3.3             89
#
#   Most visited cities  Price for 10 days pp
# 3           Reykjavik                  1200
# 4              London                  1500
# 5              Geneva                  1800
# 6           Stockholm                  1100
# 7               Viena                  1200
# 8              Moscow                   800

# %%
#Using iloc

data.iloc[3:9]
#print (data)
# Out:
#   Destinations  Feedback score  Star rating  All-inclusive  \
# 3      Iceland               1          3.5             86
# 4           UK               8          3.7             95
# 5  Switzerland               9          4.2             60
# 6       Sweden               4          3.6             99
# 7      Austria               5          4.0             45
# 8       Russia               4          3.3             89
#
#   Most visited cities  Price for 10 days pp
# 3           Reykjavik                  1200
# 4              London                  1500
# 5              Geneva                  1800
# 6           Stockholm                  1100
# 7               Viena                  1200
# 8              Moscow                   800

# %%
#Using loc

data.loc[3:8]
# Out:
#   Destinations  Feedback score  Star rating  All-inclusive  \
# 3      Iceland               1          3.5             86
# 4           UK               8          3.7             95
# 5  Switzerland               9          4.2             60
# 6       Sweden               4          3.6             99
# 7      Austria               5          4.0             45
# 8       Russia               4          3.3             89
#
#   Most visited cities  Price for 10 days pp
# 3           Reykjavik                  1200
# 4              London                  1500
# 5              Geneva                  1800
# 6           Stockholm                  1100
# 7               Viena                  1200
# 8              Moscow                   800

# %%
#Mean of all-inclusive hotels

data["All-inclusive"].mean()
# Out:
# 136.0625

# %%
data["All-inclusive"].sum()
# Out:
# 2177

# %%
#Lowest scoring destination

print(data["Feedback score"].min())

myfilter = data["Feedback score"] ==1

myfilter

low_score = data[myfilter]
low_score
# Out:
# 1
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 3       Iceland               1          3.5             86
# 9      Mongolia               1          3.2             32
# 13   Kazakhstan               1          3.0            112
#
#    Most visited cities  Price for 10 days pp
# 3            Reykjavik                  1200
# 9           Ulan-Bator                  1000
# 13              Almaty                   900

# %%
#Highest scoring destination


print(data["Feedback score"].max())
myfilter = data["Feedback score"] == 9
high_score = data[myfilter]
high_score
# Out:
# 9
#   Destinations  Feedback score  Star rating  All-inclusive  \
# 1        Italy               9          4.1            180
# 5  Switzerland               9          4.2             60
#
#   Most visited cities  Price for 10 days pp
# 1                Rome                  1000
# 5              Geneva                  1800

# %%
#All destinations where more than 100 all inclusive hotels


all_inc = data["All-inclusive"] > 10
more_all_inc = data[all_inc]
more_all_inc
# Out:
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 0         Spain               7          3.2            220
# 1         Italy               9          4.1            180
# 2      Portugal               5          3.1            134
# 3       Iceland               1          3.5             86
# 4            UK               8          3.7             95
# 5   Switzerland               9          4.2             60
# 6        Sweden               4          3.6             99
# 7       Austria               5          4.0             45
# 8        Russia               4          3.3             89
# 9      Mongolia               1          3.2             32
# 10        Japan               8          4.2             85
# 11  South Korea               3          3.9            110
# 12        China               4          3.1            230
# 13   Kazakhstan               1          3.0            112
# 14          UAE               8          4.6            260
# ...

# %%
# Score above 8

score = data ["Feedback score"]>8
score_8 = data[score]
score_8
# Out:
#   Destinations  Feedback score  Star rating  All-inclusive  \
# 1        Italy               9          4.1            180
# 5  Switzerland               9          4.2             60
#
#   Most visited cities  Price for 10 days pp
# 1                Rome                  1000
# 5              Geneva                  1800

# %%
# Score below 2

score = data ["Feedback score"]< 2
score_2 = data [score]
score_2
# Out:
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 3       Iceland               1          3.5             86
# 9      Mongolia               1          3.2             32
# 13   Kazakhstan               1          3.0            112
#
#    Most visited cities  Price for 10 days pp
# 3            Reykjavik                  1200
# 9           Ulan-Bator                  1000
# 13              Almaty                   900

# %%
# Correlation between Feedback Score and All-inclusive

data.plot.scatter(x="Feedback score", y="All-inclusive")
# Out:
# <AxesSubplot:xlabel='Feedback score', ylabel='All-inclusive'>

# %%
data.plot.scatter(x="Feedback score", y="Destinations")
# Out:
# <AxesSubplot:xlabel='Feedback score', ylabel='Destinations'>

# %%
data.corr()
# Out:
#                       Feedback score  Star rating  All-inclusive  \
# Feedback score              1.000000     0.659455       0.353617
# Star rating                 0.659455     1.000000       0.269603
# All-inclusive               0.353617     0.269603       1.000000
# Price for 10 days pp        0.416365     0.581951      -0.019561
#
#                       Price for 10 days pp
# Feedback score                    0.416365
# Star rating                       0.581951
# All-inclusive                    -0.019561
# Price for 10 days pp              1.000000

# %%
#Holidays under £1,000

print(data["Price for 10 days pp"].min())
my_filter = data["Price for 10 days pp"] <= 1000

min_price_data = data[my_filter]
min_price_data
# Out:
# 800
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 1         Italy               9          4.1            180
# 2      Portugal               5          3.1            134
# 8        Russia               4          3.3             89
# 9      Mongolia               1          3.2             32
# 13   Kazakhstan               1          3.0            112
# 15       Turkey               7          4.4            340
#
#    Most visited cities  Price for 10 days pp
# 1                 Rome                  1000
# 2               Lisbon                   900
# 8               Moscow                   800
# 9           Ulan-Bator                  1000
# 13              Almaty                   900
# 15             Antalya                  1000

# %%
#The most expensive destinations

print(data["Price for 10 days pp"].max())
my_filter = data["Price for 10 days pp"] == 1800

max_price_data = data[my_filter]
max_price_data
# Out:
# 1800
#    Destinations  Feedback score  Star rating  All-inclusive  \
# 5   Switzerland               9          4.2             60
# 11  South Korea               3          3.9            110
# 14          UAE               8          4.6            260
#
#    Most visited cities  Price for 10 days pp
# 5               Geneva                  1800
# 11               Busan                  1800
# 14               Dubai                  1800
